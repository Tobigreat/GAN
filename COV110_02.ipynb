# %% [markdown]
# <a href="https://colab.research.google.com/github/Tobigreat/GAN/blob/main/COV110_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # sample GAN

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cuda')

# %%
# Define a basic transform
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %%
# load cifar-10 dataset
train_dataset = datasets.CIFAR10(root='./data',\
              train=True, download=True, transform=transform)
dataloader = torch.utils.data.DataLoader(train_dataset, \
                                batch_size=32, shuffle=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:12<00:00, 13.1MB/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data

# %%
# define hyperparameter

# Hyperparameters
latent_dim = 100
lr = 0.0002
beta1 = 0.5
beta2 = 0.999
num_epochs = 10

# %%
# build the generator

# Define the generator
class Generator(nn.Module):
    def __init__(self, latent_dim):
        super(Generator, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(latent_dim, 128 * 8 * 8),
            nn.ReLU(),
            nn.Unflatten(1, (128, 8, 8)),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128, momentum=0.78),
            nn.ReLU(),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64, momentum=0.78),
            nn.ReLU(),
            nn.Conv2d(64, 3, kernel_size=3, padding=1),
            nn.Tanh()
        )

    def forward(self, z):
        img = self.model(z)
        return img

# %%
# Define the discriminator
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.model = nn.Sequential(
        nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1),
        nn.LeakyReLU(0.2),
        nn.Dropout(0.25),
        nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1),
        nn.ZeroPad2d((0, 1, 0, 1)),
        nn.BatchNorm2d(64, momentum=0.82),
        nn.LeakyReLU(0.25),
        nn.Dropout(0.25),
        nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
        nn.BatchNorm2d(128, momentum=0.82),
        nn.LeakyReLU(0.2),
        nn.Dropout(0.25),
        nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
        nn.BatchNorm2d(256, momentum=0.8),
        nn.LeakyReLU(0.25),
        nn.Dropout(0.25),
        nn.Flatten(),
        nn.Linear(256 * 5 * 5, 1),
        nn.Sigmoid()
    )

    def forward(self, img):
        validity = self.model(img)
        return validity

# %%
# Define the generator and discriminator
# Initialize generator and discriminator
generator = Generator(latent_dim).to(device)
discriminator = Discriminator().to(device)
# Loss function
adversarial_loss = nn.BCELoss()
# Optimizers
optimizer_G = optim.Adam(generator.parameters()\
                         , lr=lr, betas=(beta1, beta2))
optimizer_D = optim.Adam(discriminator.parameters()\
                         , lr=lr, betas=(beta1, beta2))

# %%
# Training loop
for epoch in range(num_epochs):
    for i, batch in enumerate(dataloader):
       # Convert list to tensor
        real_images = batch[0].to(device)
        # Adversarial ground truths
        valid = torch.ones(real_images.size(0), 1, device=device)
        fake = torch.zeros(real_images.size(0), 1, device=device)
        # Configure input
        real_images = real_images.to(device)

        # ---------------------
        #  Train Discriminator
        # ---------------------
        optimizer_D.zero_grad()
        # Sample noise as generator input
        z = torch.randn(real_images.size(0), latent_dim, device=device)
        # Generate a batch of images
        fake_images = generator(z)

        # Measure discriminator's ability
        # to classify real and fake images
        real_loss = adversarial_loss(discriminator\
                                     (real_images), valid)
        fake_loss = adversarial_loss(discriminator\
                                     (fake_images.detach()), fake)
        d_loss = (real_loss + fake_loss) / 2
        # Backward pass and optimize
        d_loss.backward()
        optimizer_D.step()

        # -----------------
        #  Train Generator
        # -----------------

        optimizer_G.zero_grad()
        # Generate a batch of images
        gen_images = generator(z)
        # Adversarial loss
        g_loss = adversarial_loss(discriminator(gen_images), valid)
        # Backward pass and optimize
        g_loss.backward()
        optimizer_G.step()
        # ---------------------
        #  Progress Monitoring
        # ---------------------
        if (i + 1) % 100 == 0:
            print(
                f"Epoch [{epoch+1}/{num_epochs}]\
                        Batch {i+1}/{len(dataloader)} "
                f"Discriminator Loss: {d_loss.item():.4f} "
                f"Generator Loss: {g_loss.item():.4f}"
            )
    # Save generated images for every epoch
    if (epoch + 1) % 10 == 0:
        with torch.no_grad():
            z = torch.randn(16, latent_dim, device=device)
            generated = generator(z).detach().cpu()
            grid = torchvision.utils.make_grid(generated,\
                                        nrow=4, normalize=True)
            plt.imshow(np.transpose(grid, (1, 2, 0)))
            plt.axis("off")
            plt.show()
# Out:
# Epoch [1/10]                        Batch 100/1563 Discriminator Loss: 0.5530 Generator Loss: 1.1621
# Epoch [1/10]                        Batch 200/1563 Discriminator Loss: 0.6367 Generator Loss: 0.9479
# Epoch [1/10]                        Batch 300/1563 Discriminator Loss: 0.6840 Generator Loss: 1.0768
# Epoch [1/10]                        Batch 400/1563 Discriminator Loss: 0.7331 Generator Loss: 0.8773
# Epoch [1/10]                        Batch 500/1563 Discriminator Loss: 0.6474 Generator Loss: 0.7761
# Epoch [1/10]                        Batch 600/1563 Discriminator Loss: 0.6887 Generator Loss: 1.3357
# Epoch [1/10]                        Batch 700/1563 Discriminator Loss: 0.6976 Generator Loss: 0.8884
# Epoch [1/10]                        Batch 800/1563 Discriminator Loss: 0.6619 Generator Loss: 1.0868
# Epoch [1/10]                        Batch 900/1563 Discriminator Loss: 0.6130 Generator Loss: 1.0434
# Epoch [1/10]                        Batch 1000/1563 Discriminator Loss: 0.5380 Generator Loss: 1.0208
# Epoch [1/10]                        Batch 1100/1563 Discriminator Loss: 0.6147 Generator Loss: 1.0541
# Epoch [1/10]                        Batch 1200/1563 Discriminator Loss: 0.5728 Generator Loss: 0.8884
# Epoch [1/10]                        Batch 1300/1563 Discriminator Loss: 0.7747 Generator Loss: 0.6856
# Epoch [1/10]                        Batch 1400/1563 Discriminator Loss: 0.6832 Generator Loss: 0.9482
# Epoch [1/10]                        Batch 1500/1563 Discriminator Loss: 0.6378 Generator Loss: 1.1817
# Epoch [2/10]                        Batch 100/1563 Discriminator Loss: 0.5315 Generator Loss: 1.1351
# Epoch [2/10]                        Batch 200/1563 Discriminator Loss: 0.6860 Generator Loss: 0.9722
# Epoch [2/10]                        Batch 300/1563 Discriminator Loss: 0.6783 Generator Loss: 1.1162
# Epoch [2/10]                        Batch 400/1563 Discriminator Loss: 0.7625 Generator Loss: 0.8884
# Epoch [2/10]                        Batch 500/1563 Discriminator Loss: 0.7601 Generator Loss: 0.8101
# Epoch [2/10]                        Batch 600/1563 Discriminator Loss: 0.6427 Generator Loss: 1.0321
# Epoch [2/10]                        Batch 700/1563 Discriminator Loss: 0.5679 Generator Loss: 1.1112
# Epoch [2/10]                        Batch 800/1563 Discriminator Loss: 0.5982 Generator Loss: 1.3889
# Epoch [2/10]                        Batch 900/1563 Discriminator Loss: 0.4817 Generator Loss: 0.9386
# Epoch [2/10]                        Batch 1000/1563 Discriminator Loss: 0.5924 Generator Loss: 1.2395
# Epoch [2/10]                        Batch 1100/1563 Discriminator Loss: 0.7186 Generator Loss: 0.8094
# Epoch [2/10]                        Batch 1200/1563 Discriminator Loss: 0.6399 Generator Loss: 1.1967
# Epoch [2/10]                        Batch 1300/1563 Discriminator Loss: 0.6874 Generator Loss: 0.9763
# Epoch [2/10]                        Batch 1400/1563 Discriminator Loss: 0.5806 Generator Loss: 0.9107
# Epoch [2/10]                        Batch 1500/1563 Discriminator Loss: 0.7086 Generator Loss: 0.8878
# Epoch [3/10]                        Batch 100/1563 Discriminator Loss: 0.6510 Generator Loss: 0.9199
# Epoch [3/10]                        Batch 200/1563 Discriminator Loss: 0.7888 Generator Loss: 1.2165
# Epoch [3/10]                        Batch 300/1563 Discriminator Loss: 0.5969 Generator Loss: 1.4804
# Epoch [3/10]                        Batch 400/1563 Discriminator Loss: 0.4655 Generator Loss: 1.3745
# Epoch [3/10]                        Batch 500/1563 Discriminator Loss: 0.5207 Generator Loss: 1.1192
# Epoch [3/10]                        Batch 600/1563 Discriminator Loss: 0.6014 Generator Loss: 1.1058
# Epoch [3/10]                        Batch 700/1563 Discriminator Loss: 0.4833 Generator Loss: 1.0713
# Epoch [3/10]                        Batch 800/1563 Discriminator Loss: 0.6140 Generator Loss: 0.9577
# Epoch [3/10]                        Batch 900/1563 Discriminator Loss: 0.7807 Generator Loss: 1.1474
# Epoch [3/10]                        Batch 1000/1563 Discriminator Loss: 0.7077 Generator Loss: 1.0409
# Epoch [3/10]                        Batch 1100/1563 Discriminator Loss: 0.5717 Generator Loss: 0.9778
# Epoch [3/10]                        Batch 1200/1563 Discriminator Loss: 0.6043 Generator Loss: 0.8066
# Epoch [3/10]                        Batch 1300/1563 Discriminator Loss: 0.6503 Generator Loss: 1.1888
# Epoch [3/10]                        Batch 1400/1563 Discriminator Loss: 0.6923 Generator Loss: 1.1121
# Epoch [3/10]                        Batch 1500/1563 Discriminator Loss: 0.4541 Generator Loss: 0.8486
# Epoch [4/10]                        Batch 100/1563 Discriminator Loss: 0.7904 Generator Loss: 0.6958
# Epoch [4/10]                        Batch 200/1563 Discriminator Loss: 0.5440 Generator Loss: 1.2865
# Epoch [4/10]                        Batch 300/1563 Discriminator Loss: 0.4442 Generator Loss: 1.6452
# Epoch [4/10]                        Batch 400/1563 Discriminator Loss: 0.6792 Generator Loss: 0.8909
# Epoch [4/10]                        Batch 500/1563 Discriminator Loss: 0.6168 Generator Loss: 1.1769
# Epoch [4/10]                        Batch 600/1563 Discriminator Loss: 0.5872 Generator Loss: 1.2936
# Epoch [4/10]                        Batch 700/1563 Discriminator Loss: 0.6255 Generator Loss: 0.9081
# Epoch [4/10]                        Batch 800/1563 Discriminator Loss: 0.7294 Generator Loss: 0.8541
# Epoch [4/10]                        Batch 900/1563 Discriminator Loss: 0.6045 Generator Loss: 1.2288
# Epoch [4/10]                        Batch 1000/1563 Discriminator Loss: 0.5337 Generator Loss: 0.8305
# Epoch [4/10]                        Batch 1100/1563 Discriminator Loss: 0.6665 Generator Loss: 1.0089
# Epoch [4/10]                        Batch 1200/1563 Discriminator Loss: 0.4170 Generator Loss: 1.4235
# Epoch [4/10]                        Batch 1300/1563 Discriminator Loss: 0.6884 Generator Loss: 0.8899
# Epoch [4/10]                        Batch 1400/1563 Discriminator Loss: 0.5011 Generator Loss: 1.3096
# Epoch [4/10]                        Batch 1500/1563 Discriminator Loss: 0.5370 Generator Loss: 0.8767
# Epoch [5/10]                        Batch 100/1563 Discriminator Loss: 0.6409 Generator Loss: 1.3222
# Epoch [5/10]                        Batch 200/1563 Discriminator Loss: 0.4264 Generator Loss: 1.3653
# Epoch [5/10]                        Batch 300/1563 Discriminator Loss: 0.5509 Generator Loss: 0.8269
# Epoch [5/10]                        Batch 400/1563 Discriminator Loss: 0.5865 Generator Loss: 0.9551
# Epoch [5/10]                        Batch 500/1563 Discriminator Loss: 0.4969 Generator Loss: 1.4017
# Epoch [5/10]                        Batch 600/1563 Discriminator Loss: 0.6128 Generator Loss: 1.3631
# Epoch [5/10]                        Batch 700/1563 Discriminator Loss: 0.6130 Generator Loss: 1.3045
# Epoch [5/10]                        Batch 800/1563 Discriminator Loss: 0.3620 Generator Loss: 1.3675
# Epoch [5/10]                        Batch 900/1563 Discriminator Loss: 0.5114 Generator Loss: 1.6743
# Epoch [5/10]                        Batch 1000/1563 Discriminator Loss: 0.6464 Generator Loss: 1.1613
# Epoch [5/10]                        Batch 1100/1563 Discriminator Loss: 0.4802 Generator Loss: 1.5257
# Epoch [5/10]                        Batch 1200/1563 Discriminator Loss: 0.4929 Generator Loss: 1.2088
# Epoch [5/10]                        Batch 1300/1563 Discriminator Loss: 0.5787 Generator Loss: 1.0722
# Epoch [5/10]                        Batch 1400/1563 Discriminator Loss: 0.4936 Generator Loss: 1.6050
# Epoch [5/10]                        Batch 1500/1563 Discriminator Loss: 0.6842 Generator Loss: 1.3574
# Epoch [6/10]                        Batch 100/1563 Discriminator Loss: 0.5303 Generator Loss: 1.3053
# Epoch [6/10]                        Batch 200/1563 Discriminator Loss: 0.5589 Generator Loss: 1.4424
# Epoch [6/10]                        Batch 300/1563 Discriminator Loss: 0.9813 Generator Loss: 0.8012
# Epoch [6/10]                        Batch 400/1563 Discriminator Loss: 0.4291 Generator Loss: 1.3514
# Epoch [6/10]                        Batch 500/1563 Discriminator Loss: 0.7584 Generator Loss: 0.5281
# Epoch [6/10]                        Batch 600/1563 Discriminator Loss: 0.6303 Generator Loss: 1.4983
# Epoch [6/10]                        Batch 700/1563 Discriminator Loss: 0.5462 Generator Loss: 1.7623
# Epoch [6/10]                        Batch 800/1563 Discriminator Loss: 0.7224 Generator Loss: 1.5278
# Epoch [6/10]                        Batch 900/1563 Discriminator Loss: 0.5105 Generator Loss: 1.6876
# Epoch [6/10]                        Batch 1000/1563 Discriminator Loss: 0.6116 Generator Loss: 1.1858
# Epoch [6/10]                        Batch 1100/1563 Discriminator Loss: 0.4788 Generator Loss: 1.4479
# Epoch [6/10]                        Batch 1200/1563 Discriminator Loss: 0.5562 Generator Loss: 1.6942
# Epoch [6/10]                        Batch 1300/1563 Discriminator Loss: 0.6680 Generator Loss: 1.2164
# Epoch [6/10]                        Batch 1400/1563 Discriminator Loss: 0.7398 Generator Loss: 1.1137
# Epoch [6/10]                        Batch 1500/1563 Discriminator Loss: 0.5032 Generator Loss: 1.1169
# Epoch [7/10]                        Batch 100/1563 Discriminator Loss: 0.3419 Generator Loss: 0.9163
# Epoch [7/10]                        Batch 200/1563 Discriminator Loss: 0.2862 Generator Loss: 2.4340
# Epoch [7/10]                        Batch 300/1563 Discriminator Loss: 0.5889 Generator Loss: 1.2655
# Epoch [7/10]                        Batch 400/1563 Discriminator Loss: 0.3526 Generator Loss: 2.1173
# Epoch [7/10]                        Batch 500/1563 Discriminator Loss: 0.4890 Generator Loss: 1.5043
# Epoch [7/10]                        Batch 600/1563 Discriminator Loss: 0.6952 Generator Loss: 0.8647
# Epoch [7/10]                        Batch 700/1563 Discriminator Loss: 0.6535 Generator Loss: 1.1907
# Epoch [7/10]                        Batch 800/1563 Discriminator Loss: 0.5366 Generator Loss: 1.2227
# Epoch [7/10]                        Batch 900/1563 Discriminator Loss: 0.5631 Generator Loss: 1.4362
# Epoch [7/10]                        Batch 1000/1563 Discriminator Loss: 0.5220 Generator Loss: 0.8093
# Epoch [7/10]                        Batch 1100/1563 Discriminator Loss: 0.7256 Generator Loss: 1.0337
# Epoch [7/10]                        Batch 1200/1563 Discriminator Loss: 0.3813 Generator Loss: 2.1768
# Epoch [7/10]                        Batch 1300/1563 Discriminator Loss: 0.7460 Generator Loss: 1.2331
# Epoch [7/10]                        Batch 1400/1563 Discriminator Loss: 0.5886 Generator Loss: 1.1598
# Epoch [7/10]                        Batch 1500/1563 Discriminator Loss: 0.5204 Generator Loss: 1.8204
# Epoch [8/10]                        Batch 100/1563 Discriminator Loss: 0.4700 Generator Loss: 1.9679
# Epoch [8/10]                        Batch 200/1563 Discriminator Loss: 0.7033 Generator Loss: 0.9930
# Epoch [8/10]                        Batch 300/1563 Discriminator Loss: 1.2710 Generator Loss: 1.4507
# Epoch [8/10]                        Batch 400/1563 Discriminator Loss: 0.4720 Generator Loss: 1.1166
# Epoch [8/10]                        Batch 500/1563 Discriminator Loss: 0.7388 Generator Loss: 1.0362
# Epoch [8/10]                        Batch 600/1563 Discriminator Loss: 0.5398 Generator Loss: 1.0634
# Epoch [8/10]                        Batch 700/1563 Discriminator Loss: 0.5833 Generator Loss: 0.8669
# Epoch [8/10]                        Batch 800/1563 Discriminator Loss: 0.5574 Generator Loss: 1.3289
# Epoch [8/10]                        Batch 900/1563 Discriminator Loss: 0.3617 Generator Loss: 1.6182
# Epoch [8/10]                        Batch 1000/1563 Discriminator Loss: 0.5773 Generator Loss: 1.1577
# Epoch [8/10]                        Batch 1100/1563 Discriminator Loss: 0.4402 Generator Loss: 1.1494
# Epoch [8/10]                        Batch 1200/1563 Discriminator Loss: 0.7617 Generator Loss: 0.5748
# Epoch [8/10]                        Batch 1300/1563 Discriminator Loss: 0.4632 Generator Loss: 0.9538
# Epoch [8/10]                        Batch 1400/1563 Discriminator Loss: 0.6595 Generator Loss: 1.1916
# Epoch [8/10]                        Batch 1500/1563 Discriminator Loss: 0.5811 Generator Loss: 0.9161
# Epoch [9/10]                        Batch 100/1563 Discriminator Loss: 0.6030 Generator Loss: 1.5858
# Epoch [9/10]                        Batch 200/1563 Discriminator Loss: 0.4201 Generator Loss: 1.1201
# Epoch [9/10]                        Batch 300/1563 Discriminator Loss: 0.6388 Generator Loss: 0.8793
# Epoch [9/10]                        Batch 400/1563 Discriminator Loss: 0.7527 Generator Loss: 1.0394
# Epoch [9/10]                        Batch 500/1563 Discriminator Loss: 0.5837 Generator Loss: 1.1596
# Epoch [9/10]                        Batch 600/1563 Discriminator Loss: 0.4307 Generator Loss: 1.4939
# Epoch [9/10]                        Batch 700/1563 Discriminator Loss: 0.5198 Generator Loss: 1.3085
# Epoch [9/10]                        Batch 800/1563 Discriminator Loss: 0.4756 Generator Loss: 1.2802
# Epoch [9/10]                        Batch 900/1563 Discriminator Loss: 0.6078 Generator Loss: 0.7096
# Epoch [9/10]                        Batch 1000/1563 Discriminator Loss: 0.6302 Generator Loss: 0.8324
# Epoch [9/10]                        Batch 1100/1563 Discriminator Loss: 0.4955 Generator Loss: 1.0067
# Epoch [9/10]                        Batch 1200/1563 Discriminator Loss: 0.3590 Generator Loss: 0.9292
# Epoch [9/10]                        Batch 1300/1563 Discriminator Loss: 0.6267 Generator Loss: 1.1636
# Epoch [9/10]                        Batch 1400/1563 Discriminator Loss: 0.5546 Generator Loss: 1.1384
# Epoch [9/10]                        Batch 1500/1563 Discriminator Loss: 0.5490 Generator Loss: 1.5716
# Epoch [10/10]                        Batch 100/1563 Discriminator Loss: 0.4347 Generator Loss: 1.2422
# Epoch [10/10]                        Batch 200/1563 Discriminator Loss: 0.4497 Generator Loss: 1.6233
# Epoch [10/10]                        Batch 300/1563 Discriminator Loss: 0.5621 Generator Loss: 0.9841
# Epoch [10/10]                        Batch 400/1563 Discriminator Loss: 0.4887 Generator Loss: 1.3279
# Epoch [10/10]                        Batch 500/1563 Discriminator Loss: 0.7421 Generator Loss: 0.8225
# Epoch [10/10]                        Batch 600/1563 Discriminator Loss: 0.2866 Generator Loss: 1.5587
# Epoch [10/10]                        Batch 700/1563 Discriminator Loss: 0.4789 Generator Loss: 1.2835
# Epoch [10/10]                        Batch 800/1563 Discriminator Loss: 0.5216 Generator Loss: 1.0499
# Epoch [10/10]                        Batch 900/1563 Discriminator Loss: 0.6061 Generator Loss: 1.3523
# Epoch [10/10]                        Batch 1000/1563 Discriminator Loss: 0.5454 Generator Loss: 1.6458
# Epoch [10/10]                        Batch 1100/1563 Discriminator Loss: 0.3582 Generator Loss: 1.8702
# Epoch [10/10]                        Batch 1200/1563 Discriminator Loss: 0.7612 Generator Loss: 0.9149
# Epoch [10/10]                        Batch 1300/1563 Discriminator Loss: 0.4784 Generator Loss: 0.8711
# Epoch [10/10]                        Batch 1400/1563 Discriminator Loss: 0.3924 Generator Loss: 2.5066
# Epoch [10/10]                        Batch 1500/1563 Discriminator Loss: 0.3520 Generator Loss: 1.5057

# %%
with torch.no_grad():
    z = torch.randn(16, latent_dim, device=device)
    generated = generator(z).detach().cpu()
    grid = torchvision.utils.make_grid(generated,\
                                nrow=4, normalize=True)
    plt.imshow(np.transpose(grid, (1, 2, 0)))
    plt.axis("off")
    plt.show()
